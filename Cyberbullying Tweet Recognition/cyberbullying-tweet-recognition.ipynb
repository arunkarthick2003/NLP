# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/twitterpng/twitter.png
# /kaggle/input/cyberbullying-classification/cyberbullying_tweets.csv

# %% [markdown]
# **Importing Dependencies**

# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import plotly.express as px
import nltk
import string
import emoji
from PIL import Image
from collections import Counter
from wordcloud import WordCloud,ImageColorGenerator,STOPWORDS
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem.snowball import SnowballStemmer
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
from sklearn.model_selection import train_test_split,cross_val_score,GridSearchCV,RandomizedSearchCV
from sklearn.metrics import accuracy_score,f1_score,confusion_matrix,classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier
from sklearn.svm import SVC,LinearSVC
from sklearn.naive_bayes import MultinomialNB
import pickle
from sklearn.tree import DecisionTreeClassifier
from sklearn.pipeline import Pipeline

# %% [markdown]
# **Loading the dataset**

# %%
data = pd.read_csv('/kaggle/input/cyberbullying-classification/cyberbullying_tweets.csv')
data.head()
# Out:
#                                           tweet_text cyberbullying_type
# 0  In other words #katandandre, your food was cra...  not_cyberbullying
# 1  Why is #aussietv so white? #MKR #theblock #ImA...  not_cyberbullying
# 2  @XochitlSuckkks a classy whore? Or more red ve...  not_cyberbullying
# 3  @Jason_Gio meh. :P  thanks for the heads up, b...  not_cyberbullying
# 4  @RudhoeEnglish This is an ISIS account pretend...  not_cyberbullying

# %% [markdown]
# **Analysing the dataset**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47692 entries, 0 to 47691
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_text          47692 non-null  object
#  1   cyberbullying_type  47692 non-null  object
# dtypes: object(2)
# memory usage: 745.3+ KB

# %% [markdown]
# Check for missing values

# %%
data.isnull().sum()
# Out:
# tweet_text            0
# cyberbullying_type    0
# dtype: int64

# %%
data['cyberbullying_type'].value_counts()
# Out:
# religion               7998
# age                    7992
# gender                 7973
# ethnicity              7961
# not_cyberbullying      7945
# other_cyberbullying    7823
# Name: cyberbullying_type, dtype: int64

# %% [markdown]
# **Renaming column for better understanding**

# %%
data=data.rename(columns={"tweet_text":'text','cyberbullying_type':'sentiment'})

# %%
data.head()
# Out:
#                                                 text          sentiment
# 0  In other words #katandandre, your food was cra...  not_cyberbullying
# 1  Why is #aussietv so white? #MKR #theblock #ImA...  not_cyberbullying
# 2  @XochitlSuckkks a classy whore? Or more red ve...  not_cyberbullying
# 3  @Jason_Gio meh. :P  thanks for the heads up, b...  not_cyberbullying
# 4  @RudhoeEnglish This is an ISIS account pretend...  not_cyberbullying

# %% [markdown]
# **Adding encoded column for sentiments**

# %%
data['sentiment_encoded']=data['sentiment'].replace({'religion':1,'age':2,'ethnicity':3,'gender':4,'other_cyberbullying':5,'not_cyberbullying':6})

# %%
data.head()
# Out:
#                                                 text          sentiment  \
# 0  In other words #katandandre, your food was cra...  not_cyberbullying
# 1  Why is #aussietv so white? #MKR #theblock #ImA...  not_cyberbullying
# 2  @XochitlSuckkks a classy whore? Or more red ve...  not_cyberbullying
# 3  @Jason_Gio meh. :P  thanks for the heads up, b...  not_cyberbullying
# 4  @RudhoeEnglish This is an ISIS account pretend...  not_cyberbullying
#
#    sentiment_encoded
# 0                  6
# 1                  6
# 2                  6
# 3                  6
# 4                  6

# %%
stop_words=set(stopwords.words('english'))

# %% [markdown]
# **Preprocessing of text**

# %%
#function to remove emojis as it has no value
def strip_emoji(text):
    return emoji.replace_emoji(text,replace="")

# %%
#Function to Convert text to lowercase, remove (/r, /n characters), URLs, non-utf characters, 
##Numbers, punctuations,stopwords

def strip_all_entities(text): 
    text = text.replace('\r', '').replace('\n', ' ').lower()
    text = re.sub(r"(?:\@|https?\://)\S+", "", text)
    text = re.sub(r'[^\x00-\x7f]',r'', text)
    text = re.sub(r'(.)1+', r'1', text)
    text = re.sub('[0-9]+', '', text)
    stopchars= string.punctuation
    table = str.maketrans('', '', stopchars)
    text = text.translate(table)
    text = [word for word in text.split() if word not in stop_words]
    text = ' '.join(text)
    return text

# %% [markdown]
# **Function to remove contraction**

# %%
def decontract(text):
    text = re.sub(r"can\'t", "can not", text)
    text = re.sub(r"n\'t", " not", text)
    text = re.sub(r"\'re", " are", text)
    text = re.sub(r"\'s", " is", text)
    text = re.sub(r"\'d", " would", text)
    text = re.sub(r"\'ll", " will", text)
    text = re.sub(r"\'t", " not", text)
    text = re.sub(r"\'ve", " have", text)
    text = re.sub(r"\'m", " am", text)
    return text

# %% [markdown]
# **Function to clean hashtags**

# %% [markdown]
# **Function to clean hashtags**

# %%
def clean_hashtags(tweet):
    new_tweet = " ".join(word.strip() for word in re.split('#(?!(?:hashtag)\b)[\w-]+(?=(?:\s+#[\w-]+)*\s*$)', tweet))
    new_tweet2 = " ".join(word.strip() for word in re.split('#|_', new_tweet))
    return new_tweet2

# %% [markdown]
# **Function to Filter Special Characters such as $, &**

# %%
def filter_chars(a):
    sent = []
    for word in a.split(' '):
        if ('$' in word) | ('&' in word):
            sent.append('')
        else:
            sent.append(word)
    return ' '.join(sent)

# %% [markdown]
# **Function to remove multiple sequence space**

# %%
def remove_mult_spaces(text):
    return re.sub("\s\s+" , " ", text)

# %% [markdown]
# **Function to apply stemming to words**

# %%
def stemmer(text):
    tokenized = nltk.word_tokenize(text)
    ps = PorterStemmer()
    return ' '.join([ps.stem(words) for words in tokenized])

# %% [markdown]
# **Function to apply lemmatization to words**

# %%
nltk.download('wordnet')
def lemmatizetxt(text):
    tokenized = nltk.word_tokenize(text)
    lm = WordNetLemmatizer()
    return ' '.join([lm.lemmatize(words) for words in tokenized])
# Out:
# [nltk_data] Downloading package wordnet to /usr/share/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# **Preprocessing function**

# %%
def preprocess(text):
    text = strip_emoji(text)
    text = decontract(text)
    text = strip_all_entities(text)
    text = clean_hashtags(text)
    text = filter_chars(text)
    text = remove_mult_spaces(text)
    text = stemmer(text)
#     text = lemmatizetxt(text)
    return text

# %%
data['cleaned_text'] = data['text'].apply(preprocess)
data.head()
# Out:
#                                                 text          sentiment  \
# 0  In other words #katandandre, your food was cra...  not_cyberbullying
# 1  Why is #aussietv so white? #MKR #theblock #ImA...  not_cyberbullying
# 2  @XochitlSuckkks a classy whore? Or more red ve...  not_cyberbullying
# 3  @Jason_Gio meh. :P  thanks for the heads up, b...  not_cyberbullying
# 4  @RudhoeEnglish This is an ISIS account pretend...  not_cyberbullying
#
#    sentiment_encoded                                       cleaned_text
# 0                  6                 word katandandr food crapilici mkr
# 1                  6  aussietv white mkr theblock imacelebrityau tod...
# 2                  6                     classi whore red velvet cupcak
# 3                  6  meh p thank head concern anoth angri dude twitter
# 4                  6  isi account pretend kurdish account like islam...

# %%
data['cleaned_text'].duplicated().sum()
# Out:
# 3038

# %%
data.drop_duplicates('cleaned_text',inplace=True)

# %%
data['tweet_list']=data['cleaned_text'].apply(word_tokenize)
data.head()
# Out:
#                                                 text          sentiment  \
# 0  In other words #katandandre, your food was cra...  not_cyberbullying
# 1  Why is #aussietv so white? #MKR #theblock #ImA...  not_cyberbullying
# 2  @XochitlSuckkks a classy whore? Or more red ve...  not_cyberbullying
# 3  @Jason_Gio meh. :P  thanks for the heads up, b...  not_cyberbullying
# 4  @RudhoeEnglish This is an ISIS account pretend...  not_cyberbullying
#
#    sentiment_encoded                                       cleaned_text  \
# 0                  6                 word katandandr food crapilici mkr
# 1                  6  aussietv white mkr theblock imacelebrityau tod...
# 2                  6                     classi whore red velvet cupcak
# 3                  6  meh p thank head concern anoth angri dude twitter
# 4                  6  isi account pretend kurdish account like islam...
#
#                                           tweet_list
# 0           [word, katandandr, food, crapilici, mkr]
# 1  [aussietv, white, mkr, theblock, imacelebritya...
# 2               [classi, whore, red, velvet, cupcak]
# 3  [meh, p, thank, head, concern, anoth, angri, d...
# 4  [isi, account, pretend, kurdish, account, like...

# %% [markdown]
# **Checking length of various tweet texts**

# %%
text_len=[]
for text in data.tweet_list:
    tweet_len=len(text)
    text_len.append(tweet_len)
data['text_len']=text_len

# %%
#plotting data
plt.figure(figsize=(15,8))
ax=sns.countplot(x='text_len',data=data,palette='mako')
plt.title('Count of words in tweets',fontsize=20)
plt.yticks([])
ax.bar_label(ax.containers[0])
plt.ylabel('count')
plt.xlabel('')
plt.show()

# %% [markdown]
# **Removing text without words**

# %%
data=data[data['text_len']!=0]

# %%
data.shape
# Out:
# (44653, 6)

# %% [markdown]
# **Function to create wordcloud**

# %%
def plot_wordcloud(cyberbullying_type):
    string = ""
    for i in data[data.sentiment == cyberbullying_type].cleaned_text.values:
        string = string + " " + i.strip()

    custom_mask = np.array(Image.open('/kaggle/input/twitterpng'))
    mask_colors = ImageColorGenerator(custom_mask)
    wordcloud = WordCloud(background_color ='white',max_words=2000, max_font_size=256,
               random_state=42, width=custom_mask.shape[1],height=custom_mask.shape[0],
                mask = custom_mask,min_font_size = 10,color_func=mask_colors).generate(string)
 
    # plot the WordCloud image                      
    plt.figure(figsize = (8, 8), facecolor = None)
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.tight_layout(pad = 0)
    plt.title(cyberbullying_type)
    plt.show()
    del string

# %% [markdown]
# **Splitting data based on sentiment for Data Exploration**

# %%
not_cyberbullying_type = data[data['sentiment']=='not_cyberbullying']
gender_type = data[data['sentiment']=='gender']
religion_type = data[data['sentiment']=='religion']
other_cyberbullying_type = data[data['sentiment']=='other_cyberbullying']
age_type = data[data['sentiment']=='age']
ethnicity_type = data[data['sentiment']=='ethnicity']

# %% [markdown]
# # **Exploratory data analysis**

# %% [markdown]
# **Gender based cyber bullying**

# %%
gender=Counter([item for sublist in gender_type['tweet_list'] for item in sublist])
top20_gender=pd.DataFrame(gender.most_common(20))
top20_gender.columns=['Top Words','Count']
top20_gender.style.background_gradient(cmap='Greens')
# Out:
# <style type="text/css">
# #T_17163_row0_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_17163_row1_col1 {
#   background-color: #1e8741;
#   color: #f1f1f1;
# }
# #T_17163_row2_col1 {
#   background-color: #2a924a;
#   color: #f1f1f1;
# }
# #T_17163_row3_col1 {
#   background-color: #d3eecd;
#   color: #000000;
# }
# #T_17163_row4_col1 {
#   background-color: #d9f0d3;
#   color: #000000;
# }
# #T_17163_row5_col1 {
#   background-color: #dbf1d6;
#   color: #000000;
# }
# #T_17163_row6_col1 {
#   background-color: #dff3da;
#   color: #000000;
# }
# #T_17163_row7_col1 {
#   background-color: #e1f3dc;
#   color: #000000;
# }
# #T_17163_row8_col1, #T_17163_row9_col1 {
#   background-color: #e7f6e2;
#   color: #000000;
# }
# #T_17163_row10_col1 {
#   background-color: #e8f6e3;
#   color: #000000;
# }
# #T_17163_row11_col1 {
#   background-color: #e9f7e5;
#   color: #000000;
# }
# #T_17163_row12_col1, #T_17163_row13_col1 {
#   background-color: #f1faee;
#   color: #000000;
# }
# #T_17163_row14_col1 {
#   background-color: #f2faef;
#   color: #000000;
# }
# #T_17163_row15_col1, #T_17163_row16_col1 {
#   background-color: #f2faf0;
#   color: #000000;
# }
# #T_17163_row17_col1 {
#   background-color: #f4fbf1;
#   color: #000000;
# }
# #T_17163_row18_col1 {
#   background-color: #f4fbf2;
#   color: #000000;
# }
# #T_17163_row19_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_17163_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Top Words</th>
#       <th class="col_heading level0 col1" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_17163_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_17163_row0_col0" class="data row0 col0" >joke</td>
#       <td id="T_17163_row0_col1" class="data row0 col1" >5179</td>
#     </tr>
#     <tr>
#       <th id="T_17163_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_17163_row1_col0" class="data row1 col0" >rape</td>
#       <td id="T_17163_row1_col1" class="data row1 col1" >4070</td>
#     </tr>
#     <tr>
#       <th id="T_17163_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_17163_row2_col0" class="data row2 col0" >gay</td>
#       <td id="T_17163_row2_col1" class="data row2 col1" >3852</td>
#     </tr>
#     <tr>
#       <th id="T_17163_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_17163_row3_col0" class="data row3 col0" >call</td>
#       <td id="T_17163_row3_col1" class="data row3 col1" >1401</td>
#     </tr>
#     <tr>
#       <th id="T_17163_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_17163_row4_col0" class="data row4 col0" >make</td>
#       <td id="T_17163_row4_col1" class="data row4 col1" >1283</td>
#     </tr>
#     <tr>
#       <th id="T_17163_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_17163_row5_col0" class="data row5 col0" >rt</td>
#       <td id="T_17163_row5_col1" class="data row5 col1" >1221</td>
#     </tr>
#     <tr>
#       <th id="T_17163_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_17163_row6_col0" class="data row6 col0" >bitch</td>
#       <td id="T_17163_row6_col1" class="data row6 col1" >1146</td>
#     </tr>
#     <tr>
#       <th id="T_17163_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_17163_row7_col0" class="data row7 col0" >femal</td>
#       <td id="T_17163_row7_col1" class="data row7 col1" >1108</td>
#     </tr>
#     <tr>
#       <th id="T_17163_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_17163_row8_col0" class="data row8 col0" >peopl</td>
#       <td id="T_17163_row8_col1" class="data row8 col1" >988</td>
#     </tr>
#     <tr>
#       <th id="T_17163_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_17163_row9_col0" class="data row9 col0" >like</td>
#       <td id="T_17163_row9_col1" class="data row9 col1" >978</td>
#     </tr>
#     <tr>
#       <th id="T_17163_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_17163_row10_col0" class="data row10 col0" >sexist</td>
#       <td id="T_17163_row10_col1" class="data row10 col1" >953</td>
#     </tr>
#     <tr>
#       <th id="T_17163_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_17163_row11_col0" class="data row11 col0" >women</td>
#       <td id="T_17163_row11_col1" class="data row11 col1" >895</td>
#     </tr>
#     <tr>
#       <th id="T_17163_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_17163_row12_col0" class="data row12 col0" >funni</td>
#       <td id="T_17163_row12_col1" class="data row12 col1" >662</td>
#     </tr>
#     <tr>
#       <th id="T_17163_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_17163_row13_col0" class="data row13 col0" >mkr</td>
#       <td id="T_17163_row13_col1" class="data row13 col1" >659</td>
#     </tr>
#     <tr>
#       <th id="T_17163_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_17163_row14_col0" class="data row14 col0" >men</td>
#       <td id="T_17163_row14_col1" class="data row14 col1" >614</td>
#     </tr>
#     <tr>
#       <th id="T_17163_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_17163_row15_col0" class="data row15 col0" >say</td>
#       <td id="T_17163_row15_col1" class="data row15 col1" >592</td>
#     </tr>
#     <tr>
#       <th id="T_17163_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_17163_row16_col0" class="data row16 col0" >think</td>
#       <td id="T_17163_row16_col1" class="data row16 col1" >592</td>
#     </tr>
#     <tr>
#       <th id="T_17163_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_17163_row17_col0" class="data row17 col0" >get</td>
#       <td id="T_17163_row17_col1" class="data row17 col1" >555</td>
#     </tr>
#     <tr>
#       <th id="T_17163_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_17163_row18_col0" class="data row18 col0" >fuck</td>
#       <td id="T_17163_row18_col1" class="data row18 col1" >548</td>
#     </tr>
#     <tr>
#       <th id="T_17163_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_17163_row19_col0" class="data row19 col0" >use</td>
#       <td id="T_17163_row19_col1" class="data row19 col1" >441</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig=plt.figure(figsize=(15,8))
sns.barplot(data=top20_gender,y='Count',x="Top Words")
plt.title("Top 20 words in Gender Cyberbullying")
# Out:
# Text(0.5, 1.0, 'Top 20 words in Gender Cyberbullying')

# %%
# plot_wordcloud('gender')

# %% [markdown]
# **Religion Based Cyberbullying**

# %%
religion=Counter([item for sublist in religion_type['tweet_list'] for item in sublist])
top20_religion=pd.DataFrame(religion.most_common(20))
top20_religion.columns=['Top Words','Count']
top20_religion.style.background_gradient(cmap='Greens')
# Out:
# <style type="text/css">
# #T_11abd_row0_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_11abd_row1_col1 {
#   background-color: #46ae60;
#   color: #f1f1f1;
# }
# #T_11abd_row2_col1 {
#   background-color: #87cd86;
#   color: #000000;
# }
# #T_11abd_row3_col1 {
#   background-color: #a3da9d;
#   color: #000000;
# }
# #T_11abd_row4_col1 {
#   background-color: #d4eece;
#   color: #000000;
# }
# #T_11abd_row5_col1 {
#   background-color: #d8f0d2;
#   color: #000000;
# }
# #T_11abd_row6_col1 {
#   background-color: #ddf2d8;
#   color: #000000;
# }
# #T_11abd_row7_col1 {
#   background-color: #def2d9;
#   color: #000000;
# }
# #T_11abd_row8_col1 {
#   background-color: #e0f3db;
#   color: #000000;
# }
# #T_11abd_row9_col1 {
#   background-color: #e4f5df;
#   color: #000000;
# }
# #T_11abd_row10_col1 {
#   background-color: #e7f6e3;
#   color: #000000;
# }
# #T_11abd_row11_col1 {
#   background-color: #e8f6e4;
#   color: #000000;
# }
# #T_11abd_row12_col1 {
#   background-color: #edf8ea;
#   color: #000000;
# }
# #T_11abd_row13_col1 {
#   background-color: #f2faef;
#   color: #000000;
# }
# #T_11abd_row14_col1, #T_11abd_row15_col1 {
#   background-color: #f4fbf1;
#   color: #000000;
# }
# #T_11abd_row16_col1 {
#   background-color: #f4fbf2;
#   color: #000000;
# }
# #T_11abd_row17_col1, #T_11abd_row18_col1 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_11abd_row19_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_11abd_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Top Words</th>
#       <th class="col_heading level0 col1" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_11abd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_11abd_row0_col0" class="data row0 col0" >muslim</td>
#       <td id="T_11abd_row0_col1" class="data row0 col1" >4618</td>
#     </tr>
#     <tr>
#       <th id="T_11abd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_11abd_row1_col0" class="data row1 col0" >idiot</td>
#       <td id="T_11abd_row1_col1" class="data row1 col1" >3075</td>
#     </tr>
#     <tr>
#       <th id="T_11abd_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_11abd_row2_col0" class="data row2 col0" >islam</td>
#       <td id="T_11abd_row2_col1" class="data row2 col1" >2440</td>
#     </tr>
#     <tr>
#       <th id="T_11abd_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_11abd_row3_col0" class="data row3 col0" >christian</td>
#       <td id="T_11abd_row3_col1" class="data row3 col1" >2132</td>
#     </tr>
#     <tr>
#       <th id="T_11abd_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_11abd_row4_col0" class="data row4 col0" >u</td>
#       <td id="T_11abd_row4_col1" class="data row4 col1" >1449</td>
#     </tr>
#     <tr>
#       <th id="T_11abd_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_11abd_row5_col0" class="data row5 col0" >terrorist</td>
#       <td id="T_11abd_row5_col1" class="data row5 col1" >1379</td>
#     </tr>
#     <tr>
#       <th id="T_11abd_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_11abd_row6_col0" class="data row6 col0" >right</td>
#       <td id="T_11abd_row6_col1" class="data row6 col1" >1290</td>
#     </tr>
#     <tr>
#       <th id="T_11abd_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_11abd_row7_col0" class="data row7 col0" >like</td>
#       <td id="T_11abd_row7_col1" class="data row7 col1" >1276</td>
#     </tr>
#     <tr>
#       <th id="T_11abd_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_11abd_row8_col0" class="data row8 col0" >support</td>
#       <td id="T_11abd_row8_col1" class="data row8 col1" >1251</td>
#     </tr>
#     <tr>
#       <th id="T_11abd_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_11abd_row9_col0" class="data row9 col0" >terror</td>
#       <td id="T_11abd_row9_col1" class="data row9 col1" >1182</td>
#     </tr>
#     <tr>
#       <th id="T_11abd_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_11abd_row10_col0" class="data row10 col0" >radic</td>
#       <td id="T_11abd_row10_col1" class="data row10 col1" >1110</td>
#     </tr>
#     <tr>
#       <th id="T_11abd_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_11abd_row11_col0" class="data row11 col0" >peopl</td>
#       <td id="T_11abd_row11_col1" class="data row11 col1" >1076</td>
#     </tr>
#     <tr>
#       <th id="T_11abd_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_11abd_row12_col0" class="data row12 col0" >woman</td>
#       <td id="T_11abd_row12_col1" class="data row12 col1" >938</td>
#     </tr>
#     <tr>
#       <th id="T_11abd_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_11abd_row13_col0" class="data row13 col0" >say</td>
#       <td id="T_11abd_row13_col1" class="data row13 col1" >812</td>
#     </tr>
#     <tr>
#       <th id="T_11abd_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_11abd_row14_col0" class="data row14 col0" >amp</td>
#       <td id="T_11abd_row14_col1" class="data row14 col1" >769</td>
#     </tr>
#     <tr>
#       <th id="T_11abd_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_11abd_row15_col0" class="data row15 col0" >know</td>
#       <td id="T_11abd_row15_col1" class="data row15 col1" >759</td>
#     </tr>
#     <tr>
#       <th id="T_11abd_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_11abd_row16_col0" class="data row16 col0" >human</td>
#       <td id="T_11abd_row16_col1" class="data row16 col1" >745</td>
#     </tr>
#     <tr>
#       <th id="T_11abd_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_11abd_row17_col0" class="data row17 col0" >kill</td>
#       <td id="T_11abd_row17_col1" class="data row17 col1" >708</td>
#     </tr>
#     <tr>
#       <th id="T_11abd_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_11abd_row18_col0" class="data row18 col0" >hindu</td>
#       <td id="T_11abd_row18_col1" class="data row18 col1" >688</td>
#     </tr>
#     <tr>
#       <th id="T_11abd_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_11abd_row19_col0" class="data row19 col0" >one</td>
#       <td id="T_11abd_row19_col1" class="data row19 col1" >666</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig=plt.figure(figsize=(15,8))
sns.barplot(data=top20_religion,y='Count',x="Top Words")
plt.title("Top 20 words in Religion Cyberbullying")
# Out:
# Text(0.5, 1.0, 'Top 20 words in Religion Cyberbullying')

# %%
# plot_wordcloud('religion')

# %% [markdown]
# **Age based cyberbullying**

# %%
age=Counter([item for sublist in age_type['tweet_list'] for item in sublist])
top20_age=pd.DataFrame(age.most_common(20))
top20_age.columns=['Top Words','Count']
top20_age.style.background_gradient(cmap='Greens')
# Out:
# <style type="text/css">
# #T_8b66a_row0_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_8b66a_row1_col1 {
#   background-color: #005622;
#   color: #f1f1f1;
# }
# #T_8b66a_row2_col1 {
#   background-color: #6bc072;
#   color: #000000;
# }
# #T_8b66a_row3_col1 {
#   background-color: #78c679;
#   color: #000000;
# }
# #T_8b66a_row4_col1 {
#   background-color: #d6efd0;
#   color: #000000;
# }
# #T_8b66a_row5_col1, #T_8b66a_row6_col1 {
#   background-color: #edf8ea;
#   color: #000000;
# }
# #T_8b66a_row7_col1 {
#   background-color: #eff9ec;
#   color: #000000;
# }
# #T_8b66a_row8_col1, #T_8b66a_row9_col1 {
#   background-color: #f1faee;
#   color: #000000;
# }
# #T_8b66a_row10_col1 {
#   background-color: #f2faf0;
#   color: #000000;
# }
# #T_8b66a_row11_col1 {
#   background-color: #f3faf0;
#   color: #000000;
# }
# #T_8b66a_row12_col1 {
#   background-color: #f4fbf2;
#   color: #000000;
# }
# #T_8b66a_row13_col1 {
#   background-color: #f5fbf2;
#   color: #000000;
# }
# #T_8b66a_row14_col1 {
#   background-color: #f5fbf3;
#   color: #000000;
# }
# #T_8b66a_row15_col1, #T_8b66a_row16_col1, #T_8b66a_row17_col1, #T_8b66a_row18_col1 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_8b66a_row19_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_8b66a_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Top Words</th>
#       <th class="col_heading level0 col1" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8b66a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8b66a_row0_col0" class="data row0 col0" >bulli</td>
#       <td id="T_8b66a_row0_col1" class="data row0 col1" >8899</td>
#     </tr>
#     <tr>
#       <th id="T_8b66a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8b66a_row1_col0" class="data row1 col0" >school</td>
#       <td id="T_8b66a_row1_col1" class="data row1 col1" >8426</td>
#     </tr>
#     <tr>
#       <th id="T_8b66a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8b66a_row2_col0" class="data row2 col0" >high</td>
#       <td id="T_8b66a_row2_col1" class="data row2 col1" >4861</td>
#     </tr>
#     <tr>
#       <th id="T_8b66a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8b66a_row3_col0" class="data row3 col0" >girl</td>
#       <td id="T_8b66a_row3_col1" class="data row3 col1" >4616</td>
#     </tr>
#     <tr>
#       <th id="T_8b66a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8b66a_row4_col0" class="data row4 col0" >like</td>
#       <td id="T_8b66a_row4_col1" class="data row4 col1" >2076</td>
#     </tr>
#     <tr>
#       <th id="T_8b66a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_8b66a_row5_col0" class="data row5 col0" >get</td>
#       <td id="T_8b66a_row5_col1" class="data row5 col1" >1051</td>
#     </tr>
#     <tr>
#       <th id="T_8b66a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_8b66a_row6_col0" class="data row6 col0" >one</td>
#       <td id="T_8b66a_row6_col1" class="data row6 col1" >1044</td>
#     </tr>
#     <tr>
#       <th id="T_8b66a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_8b66a_row7_col0" class="data row7 col0" >peopl</td>
#       <td id="T_8b66a_row7_col1" class="data row7 col1" >934</td>
#     </tr>
#     <tr>
#       <th id="T_8b66a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_8b66a_row8_col0" class="data row8 col0" >got</td>
#       <td id="T_8b66a_row8_col1" class="data row8 col1" >842</td>
#     </tr>
#     <tr>
#       <th id="T_8b66a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_8b66a_row9_col0" class="data row9 col0" >kid</td>
#       <td id="T_8b66a_row9_col1" class="data row9 col1" >809</td>
#     </tr>
#     <tr>
#       <th id="T_8b66a_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_8b66a_row10_col0" class="data row10 col0" >would</td>
#       <td id="T_8b66a_row10_col1" class="data row10 col1" >762</td>
#     </tr>
#     <tr>
#       <th id="T_8b66a_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_8b66a_row11_col0" class="data row11 col0" >middl</td>
#       <td id="T_8b66a_row11_col1" class="data row11 col1" >714</td>
#     </tr>
#     <tr>
#       <th id="T_8b66a_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_8b66a_row12_col0" class="data row12 col0" >friend</td>
#       <td id="T_8b66a_row12_col1" class="data row12 col1" >632</td>
#     </tr>
#     <tr>
#       <th id="T_8b66a_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_8b66a_row13_col0" class="data row13 col0" >im</td>
#       <td id="T_8b66a_row13_col1" class="data row13 col1" >625</td>
#     </tr>
#     <tr>
#       <th id="T_8b66a_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_8b66a_row14_col0" class="data row14 col0" >year</td>
#       <td id="T_8b66a_row14_col1" class="data row14 col1" >586</td>
#     </tr>
#     <tr>
#       <th id="T_8b66a_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_8b66a_row15_col0" class="data row15 col0" >go</td>
#       <td id="T_8b66a_row15_col1" class="data row15 col1" >555</td>
#     </tr>
#     <tr>
#       <th id="T_8b66a_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_8b66a_row16_col0" class="data row16 col0" >look</td>
#       <td id="T_8b66a_row16_col1" class="data row16 col1" >545</td>
#     </tr>
#     <tr>
#       <th id="T_8b66a_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_8b66a_row17_col0" class="data row17 col0" >amp</td>
#       <td id="T_8b66a_row17_col1" class="data row17 col1" >527</td>
#     </tr>
#     <tr>
#       <th id="T_8b66a_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_8b66a_row18_col0" class="data row18 col0" >know</td>
#       <td id="T_8b66a_row18_col1" class="data row18 col1" >511</td>
#     </tr>
#     <tr>
#       <th id="T_8b66a_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_8b66a_row19_col0" class="data row19 col0" >think</td>
#       <td id="T_8b66a_row19_col1" class="data row19 col1" >467</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig=plt.figure(figsize=(15,8))
sns.barplot(data=top20_age,y='Count',x='Top Words')
plt.title('Top 20 words in age cyberbullying')
# Out:
# Text(0.5, 1.0, 'Top 20 words in age cyberbullying')

# %%
# plot_wordcloud('age')

# %% [markdown]
# **Ethnicity based cyberbullying**

# %%
ethnicity=Counter([item for sublist in ethnicity_type['tweet_list'] for item in sublist])
top20_ethnicity = pd.DataFrame(ethnicity.most_common(20))
top20_ethnicity.columns = ['Top Words','Count']
top20_ethnicity.style.background_gradient(cmap='Greens')
# Out:
# <style type="text/css">
# #T_d4240_row0_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_d4240_row1_col1 {
#   background-color: #005f26;
#   color: #f1f1f1;
# }
# #T_d4240_row2_col1 {
#   background-color: #0c7735;
#   color: #f1f1f1;
# }
# #T_d4240_row3_col1 {
#   background-color: #b8e3b2;
#   color: #000000;
# }
# #T_d4240_row4_col1 {
#   background-color: #bee5b8;
#   color: #000000;
# }
# #T_d4240_row5_col1 {
#   background-color: #d0edca;
#   color: #000000;
# }
# #T_d4240_row6_col1 {
#   background-color: #dbf1d6;
#   color: #000000;
# }
# #T_d4240_row7_col1 {
#   background-color: #e3f4de;
#   color: #000000;
# }
# #T_d4240_row8_col1 {
#   background-color: #e9f7e5;
#   color: #000000;
# }
# #T_d4240_row9_col1 {
#   background-color: #eaf7e6;
#   color: #000000;
# }
# #T_d4240_row10_col1 {
#   background-color: #ecf8e8;
#   color: #000000;
# }
# #T_d4240_row11_col1 {
#   background-color: #edf8e9;
#   color: #000000;
# }
# #T_d4240_row12_col1 {
#   background-color: #edf8ea;
#   color: #000000;
# }
# #T_d4240_row13_col1 {
#   background-color: #eff9eb;
#   color: #000000;
# }
# #T_d4240_row14_col1 {
#   background-color: #eff9ec;
#   color: #000000;
# }
# #T_d4240_row15_col1 {
#   background-color: #f4fbf1;
#   color: #000000;
# }
# #T_d4240_row16_col1, #T_d4240_row17_col1 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_d4240_row18_col1, #T_d4240_row19_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_d4240_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Top Words</th>
#       <th class="col_heading level0 col1" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d4240_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d4240_row0_col0" class="data row0 col0" >fuck</td>
#       <td id="T_d4240_row0_col1" class="data row0 col1" >5892</td>
#     </tr>
#     <tr>
#       <th id="T_d4240_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d4240_row1_col0" class="data row1 col0" >nigger</td>
#       <td id="T_d4240_row1_col1" class="data row1 col1" >5456</td>
#     </tr>
#     <tr>
#       <th id="T_d4240_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d4240_row2_col0" class="data row2 col0" >dumb</td>
#       <td id="T_d4240_row2_col1" class="data row2 col1" >5003</td>
#     </tr>
#     <tr>
#       <th id="T_d4240_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d4240_row3_col0" class="data row3 col0" >ass</td>
#       <td id="T_d4240_row3_col1" class="data row3 col1" >2241</td>
#     </tr>
#     <tr>
#       <th id="T_d4240_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d4240_row4_col0" class="data row4 col0" >black</td>
#       <td id="T_d4240_row4_col1" class="data row4 col1" >2134</td>
#     </tr>
#     <tr>
#       <th id="T_d4240_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d4240_row5_col0" class="data row5 col0" >u</td>
#       <td id="T_d4240_row5_col1" class="data row5 col1" >1789</td>
#     </tr>
#     <tr>
#       <th id="T_d4240_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d4240_row6_col0" class="data row6 col0" >white</td>
#       <td id="T_d4240_row6_col1" class="data row6 col1" >1557</td>
#     </tr>
#     <tr>
#       <th id="T_d4240_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d4240_row7_col0" class="data row7 col0" >call</td>
#       <td id="T_d4240_row7_col1" class="data row7 col1" >1381</td>
#     </tr>
#     <tr>
#       <th id="T_d4240_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d4240_row8_col0" class="data row8 col0" >peopl</td>
#       <td id="T_d4240_row8_col1" class="data row8 col1" >1182</td>
#     </tr>
#     <tr>
#       <th id="T_d4240_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d4240_row9_col0" class="data row9 col0" >rt</td>
#       <td id="T_d4240_row9_col1" class="data row9 col1" >1166</td>
#     </tr>
#     <tr>
#       <th id="T_d4240_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_d4240_row10_col0" class="data row10 col0" >obama</td>
#       <td id="T_d4240_row10_col1" class="data row10 col1" >1112</td>
#     </tr>
#     <tr>
#       <th id="T_d4240_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_d4240_row11_col0" class="data row11 col0" >one</td>
#       <td id="T_d4240_row11_col1" class="data row11 col1" >1058</td>
#     </tr>
#     <tr>
#       <th id="T_d4240_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_d4240_row12_col0" class="data row12 col0" >like</td>
#       <td id="T_d4240_row12_col1" class="data row12 col1" >1035</td>
#     </tr>
#     <tr>
#       <th id="T_d4240_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_d4240_row13_col0" class="data row13 col0" >bitch</td>
#       <td id="T_d4240_row13_col1" class="data row13 col1" >999</td>
#     </tr>
#     <tr>
#       <th id="T_d4240_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_d4240_row14_col0" class="data row14 col0" >ur</td>
#       <td id="T_d4240_row14_col1" class="data row14 col1" >987</td>
#     </tr>
#     <tr>
#       <th id="T_d4240_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_d4240_row15_col0" class="data row15 col0" >say</td>
#       <td id="T_d4240_row15_col1" class="data row15 col1" >817</td>
#     </tr>
#     <tr>
#       <th id="T_d4240_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_d4240_row16_col0" class="data row16 col0" >first</td>
#       <td id="T_d4240_row16_col1" class="data row16 col1" >745</td>
#     </tr>
#     <tr>
#       <th id="T_d4240_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_d4240_row17_col0" class="data row17 col0" >get</td>
#       <td id="T_d4240_row17_col1" class="data row17 col1" >740</td>
#     </tr>
#     <tr>
#       <th id="T_d4240_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_d4240_row18_col0" class="data row18 col0" >anyth</td>
#       <td id="T_d4240_row18_col1" class="data row18 col1" >708</td>
#     </tr>
#     <tr>
#       <th id="T_d4240_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_d4240_row19_col0" class="data row19 col0" >racism</td>
#       <td id="T_d4240_row19_col1" class="data row19 col1" >689</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig = plt.figure(figsize=(15,8))
sns.barplot(data=top20_ethnicity, y="Count", x="Top Words")
plt.title("Top 20 words in Ethnicity Cyberbullying")
# Out:
# Text(0.5, 1.0, 'Top 20 words in Ethnicity Cyberbullying')

# %%
# plot_wordcloud('ethnicity')

# %% [markdown]
# **Other types of cyberbullying**

# %%
other_cyberbullying = Counter([item for sublist in other_cyberbullying_type['tweet_list'] for item in sublist])
top20_other_cyberbullying = pd.DataFrame(other_cyberbullying.most_common(20))
top20_other_cyberbullying.columns = ['Top Words','Count']
top20_other_cyberbullying.style.background_gradient(cmap='Greens')
# Out:
# <style type="text/css">
# #T_465d1_row0_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_465d1_row1_col1 {
#   background-color: #1a843f;
#   color: #f1f1f1;
# }
# #T_465d1_row2_col1 {
#   background-color: #7fc97f;
#   color: #000000;
# }
# #T_465d1_row3_col1 {
#   background-color: #a8dca2;
#   color: #000000;
# }
# #T_465d1_row4_col1 {
#   background-color: #b6e2af;
#   color: #000000;
# }
# #T_465d1_row5_col1 {
#   background-color: #c7e9c0;
#   color: #000000;
# }
# #T_465d1_row6_col1 {
#   background-color: #e1f3dc;
#   color: #000000;
# }
# #T_465d1_row7_col1 {
#   background-color: #e5f5e1;
#   color: #000000;
# }
# #T_465d1_row8_col1 {
#   background-color: #eaf7e6;
#   color: #000000;
# }
# #T_465d1_row9_col1, #T_465d1_row10_col1 {
#   background-color: #ebf7e7;
#   color: #000000;
# }
# #T_465d1_row11_col1 {
#   background-color: #eff9ec;
#   color: #000000;
# }
# #T_465d1_row12_col1 {
#   background-color: #f1faee;
#   color: #000000;
# }
# #T_465d1_row13_col1 {
#   background-color: #f2faef;
#   color: #000000;
# }
# #T_465d1_row14_col1 {
#   background-color: #f2faf0;
#   color: #000000;
# }
# #T_465d1_row15_col1, #T_465d1_row16_col1, #T_465d1_row17_col1, #T_465d1_row18_col1 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_465d1_row19_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_465d1_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Top Words</th>
#       <th class="col_heading level0 col1" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_465d1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_465d1_row0_col0" class="data row0 col0" >bulli</td>
#       <td id="T_465d1_row0_col1" class="data row0 col1" >882</td>
#     </tr>
#     <tr>
#       <th id="T_465d1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_465d1_row1_col0" class="data row1 col0" >rt</td>
#       <td id="T_465d1_row1_col1" class="data row1 col1" >727</td>
#     </tr>
#     <tr>
#       <th id="T_465d1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_465d1_row2_col0" class="data row2 col0" >fuck</td>
#       <td id="T_465d1_row2_col1" class="data row2 col1" >509</td>
#     </tr>
#     <tr>
#       <th id="T_465d1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_465d1_row3_col0" class="data row3 col0" >like</td>
#       <td id="T_465d1_row3_col1" class="data row3 col1" >424</td>
#     </tr>
#     <tr>
#       <th id="T_465d1_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_465d1_row4_col0" class="data row4 col0" >get</td>
#       <td id="T_465d1_row4_col1" class="data row4 col1" >393</td>
#     </tr>
#     <tr>
#       <th id="T_465d1_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_465d1_row5_col0" class="data row5 col0" >peopl</td>
#       <td id="T_465d1_row5_col1" class="data row5 col1" >353</td>
#     </tr>
#     <tr>
#       <th id="T_465d1_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_465d1_row6_col0" class="data row6 col0" >go</td>
#       <td id="T_465d1_row6_col1" class="data row6 col1" >277</td>
#     </tr>
#     <tr>
#       <th id="T_465d1_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_465d1_row7_col0" class="data row7 col0" >idiot</td>
#       <td id="T_465d1_row7_col1" class="data row7 col1" >261</td>
#     </tr>
#     <tr>
#       <th id="T_465d1_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_465d1_row8_col0" class="data row8 col0" >know</td>
#       <td id="T_465d1_row8_col1" class="data row8 col1" >241</td>
#     </tr>
#     <tr>
#       <th id="T_465d1_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_465d1_row9_col0" class="data row9 col0" >think</td>
#       <td id="T_465d1_row9_col1" class="data row9 col1" >237</td>
#     </tr>
#     <tr>
#       <th id="T_465d1_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_465d1_row10_col0" class="data row10 col0" >would</td>
#       <td id="T_465d1_row10_col1" class="data row10 col1" >235</td>
#     </tr>
#     <tr>
#       <th id="T_465d1_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_465d1_row11_col0" class="data row11 col0" >make</td>
#       <td id="T_465d1_row11_col1" class="data row11 col1" >215</td>
#     </tr>
#     <tr>
#       <th id="T_465d1_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_465d1_row12_col0" class="data row12 col0" >one</td>
#       <td id="T_465d1_row12_col1" class="data row12 col1" >205</td>
#     </tr>
#     <tr>
#       <th id="T_465d1_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_465d1_row13_col0" class="data row13 col0" >time</td>
#       <td id="T_465d1_row13_col1" class="data row13 col1" >202</td>
#     </tr>
#     <tr>
#       <th id="T_465d1_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_465d1_row14_col0" class="data row14 col0" >hate</td>
#       <td id="T_465d1_row14_col1" class="data row14 col1" >199</td>
#     </tr>
#     <tr>
#       <th id="T_465d1_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_465d1_row15_col0" class="data row15 col0" >want</td>
#       <td id="T_465d1_row15_col1" class="data row15 col1" >183</td>
#     </tr>
#     <tr>
#       <th id="T_465d1_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_465d1_row16_col0" class="data row16 col0" >thing</td>
#       <td id="T_465d1_row16_col1" class="data row16 col1" >182</td>
#     </tr>
#     <tr>
#       <th id="T_465d1_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_465d1_row17_col0" class="data row17 col0" >need</td>
#       <td id="T_465d1_row17_col1" class="data row17 col1" >182</td>
#     </tr>
#     <tr>
#       <th id="T_465d1_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_465d1_row18_col0" class="data row18 col0" >see</td>
#       <td id="T_465d1_row18_col1" class="data row18 col1" >178</td>
#     </tr>
#     <tr>
#       <th id="T_465d1_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_465d1_row19_col0" class="data row19 col0" >got</td>
#       <td id="T_465d1_row19_col1" class="data row19 col1" >175</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig = plt.figure(figsize=(15,8))
sns.barplot(data=top20_other_cyberbullying, y="Count", x="Top Words")
plt.title("Top 20 words in Other Cyberbullying")
# Out:
# Text(0.5, 1.0, 'Top 20 words in Other Cyberbullying')

# %%
# plot_wordcloud('other_cyberbullying')

# %% [markdown]
# **Tweets without Cyberbullying**

# %%
not_cyberbullying = Counter([item for sublist in not_cyberbullying_type['tweet_list'] for item in sublist])
top20_not_cyberbullying = pd.DataFrame(not_cyberbullying.most_common(20))
top20_not_cyberbullying.columns = ['Top Words','Count']
top20_not_cyberbullying.style.background_gradient(cmap='Greens')
# Out:
# <style type="text/css">
# #T_0faa5_row0_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_0faa5_row1_col1 {
#   background-color: #45ad5f;
#   color: #f1f1f1;
# }
# #T_0faa5_row2_col1 {
#   background-color: #98d594;
#   color: #000000;
# }
# #T_0faa5_row3_col1, #T_0faa5_row4_col1 {
#   background-color: #ddf2d8;
#   color: #000000;
# }
# #T_0faa5_row5_col1 {
#   background-color: #e2f4dd;
#   color: #000000;
# }
# #T_0faa5_row6_col1 {
#   background-color: #e5f5e0;
#   color: #000000;
# }
# #T_0faa5_row7_col1, #T_0faa5_row8_col1 {
#   background-color: #eef8ea;
#   color: #000000;
# }
# #T_0faa5_row9_col1 {
#   background-color: #eff9ec;
#   color: #000000;
# }
# #T_0faa5_row10_col1 {
#   background-color: #f0f9ec;
#   color: #000000;
# }
# #T_0faa5_row11_col1 {
#   background-color: #f0f9ed;
#   color: #000000;
# }
# #T_0faa5_row12_col1 {
#   background-color: #f2faef;
#   color: #000000;
# }
# #T_0faa5_row13_col1 {
#   background-color: #f3faf0;
#   color: #000000;
# }
# #T_0faa5_row14_col1 {
#   background-color: #f4fbf1;
#   color: #000000;
# }
# #T_0faa5_row15_col1 {
#   background-color: #f4fbf2;
#   color: #000000;
# }
# #T_0faa5_row16_col1 {
#   background-color: #f5fbf3;
#   color: #000000;
# }
# #T_0faa5_row17_col1 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_0faa5_row18_col1, #T_0faa5_row19_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_0faa5_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Top Words</th>
#       <th class="col_heading level0 col1" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0faa5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0faa5_row0_col0" class="data row0 col0" >mkr</td>
#       <td id="T_0faa5_row0_col1" class="data row0 col1" >1674</td>
#     </tr>
#     <tr>
#       <th id="T_0faa5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0faa5_row1_col0" class="data row1 col0" >bulli</td>
#       <td id="T_0faa5_row1_col1" class="data row1 col1" >1102</td>
#     </tr>
#     <tr>
#       <th id="T_0faa5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0faa5_row2_col0" class="data row2 col0" >rt</td>
#       <td id="T_0faa5_row2_col1" class="data row2 col1" >785</td>
#     </tr>
#     <tr>
#       <th id="T_0faa5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0faa5_row3_col0" class="data row3 col0" >like</td>
#       <td id="T_0faa5_row3_col1" class="data row3 col1" >424</td>
#     </tr>
#     <tr>
#       <th id="T_0faa5_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0faa5_row4_col0" class="data row4 col0" >get</td>
#       <td id="T_0faa5_row4_col1" class="data row4 col1" >423</td>
#     </tr>
#     <tr>
#       <th id="T_0faa5_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0faa5_row5_col0" class="data row5 col0" >go</td>
#       <td id="T_0faa5_row5_col1" class="data row5 col1" >394</td>
#     </tr>
#     <tr>
#       <th id="T_0faa5_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_0faa5_row6_col0" class="data row6 col0" >school</td>
#       <td id="T_0faa5_row6_col1" class="data row6 col1" >374</td>
#     </tr>
#     <tr>
#       <th id="T_0faa5_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_0faa5_row7_col0" class="data row7 col0" >kat</td>
#       <td id="T_0faa5_row7_col1" class="data row7 col1" >286</td>
#     </tr>
#     <tr>
#       <th id="T_0faa5_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_0faa5_row8_col0" class="data row8 col0" >would</td>
#       <td id="T_0faa5_row8_col1" class="data row8 col1" >286</td>
#     </tr>
#     <tr>
#       <th id="T_0faa5_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_0faa5_row9_col0" class="data row9 col0" >peopl</td>
#       <td id="T_0faa5_row9_col1" class="data row9 col1" >272</td>
#     </tr>
#     <tr>
#       <th id="T_0faa5_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_0faa5_row10_col0" class="data row10 col0" >one</td>
#       <td id="T_0faa5_row10_col1" class="data row10 col1" >264</td>
#     </tr>
#     <tr>
#       <th id="T_0faa5_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_0faa5_row11_col0" class="data row11 col0" >amp</td>
#       <td id="T_0faa5_row11_col1" class="data row11 col1" >258</td>
#     </tr>
#     <tr>
#       <th id="T_0faa5_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_0faa5_row12_col0" class="data row12 col0" >think</td>
#       <td id="T_0faa5_row12_col1" class="data row12 col1" >242</td>
#     </tr>
#     <tr>
#       <th id="T_0faa5_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_0faa5_row13_col0" class="data row13 col0" >know</td>
#       <td id="T_0faa5_row13_col1" class="data row13 col1" >229</td>
#     </tr>
#     <tr>
#       <th id="T_0faa5_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_0faa5_row14_col0" class="data row14 col0" >time</td>
#       <td id="T_0faa5_row14_col1" class="data row14 col1" >224</td>
#     </tr>
#     <tr>
#       <th id="T_0faa5_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_0faa5_row15_col0" class="data row15 col0" >make</td>
#       <td id="T_0faa5_row15_col1" class="data row15 col1" >219</td>
#     </tr>
#     <tr>
#       <th id="T_0faa5_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_0faa5_row16_col0" class="data row16 col0" >love</td>
#       <td id="T_0faa5_row16_col1" class="data row16 col1" >207</td>
#     </tr>
#     <tr>
#       <th id="T_0faa5_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_0faa5_row17_col0" class="data row17 col0" >andr</td>
#       <td id="T_0faa5_row17_col1" class="data row17 col1" >194</td>
#     </tr>
#     <tr>
#       <th id="T_0faa5_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_0faa5_row18_col0" class="data row18 col0" >need</td>
#       <td id="T_0faa5_row18_col1" class="data row18 col1" >191</td>
#     </tr>
#     <tr>
#       <th id="T_0faa5_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_0faa5_row19_col0" class="data row19 col0" >fuck</td>
#       <td id="T_0faa5_row19_col1" class="data row19 col1" >188</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig = plt.figure(figsize=(15,8))
sns.barplot(data=top20_not_cyberbullying, y="Count", x="Top Words")
plt.title("Top 20 words in Not Cyberbullying")
# Out:
# Text(0.5, 1.0, 'Top 20 words in Not Cyberbullying')

# %%
# plot_wordcloud('not_cyberbullying')

# %%
data.head()
# Out:
#                                                 text          sentiment  \
# 0  In other words #katandandre, your food was cra...  not_cyberbullying
# 1  Why is #aussietv so white? #MKR #theblock #ImA...  not_cyberbullying
# 2  @XochitlSuckkks a classy whore? Or more red ve...  not_cyberbullying
# 3  @Jason_Gio meh. :P  thanks for the heads up, b...  not_cyberbullying
# 4  @RudhoeEnglish This is an ISIS account pretend...  not_cyberbullying
#
#    sentiment_encoded                                       cleaned_text  \
# 0                  6                 word katandandr food crapilici mkr
# 1                  6  aussietv white mkr theblock imacelebrityau tod...
# 2                  6                     classi whore red velvet cupcak
# 3                  6  meh p thank head concern anoth angri dude twitter
# 4                  6  isi account pretend kurdish account like islam...
#
#                                           tweet_list  text_len
# 0           [word, katandandr, food, crapilici, mkr]         5
# 1  [aussietv, white, mkr, theblock, imacelebritya...        11
# 2               [classi, whore, red, velvet, cupcak]         5
# 3  [meh, p, thank, head, concern, anoth, angri, d...         9
# 4  [isi, account, pretend, kurdish, account, like...         8

# %%
sentiments = ["religion", "age", "ethnicity", "gender", "other_cyberbullying","not_cyberbullying"]

# %% [markdown]
# **Splitting Data into Train and Test Sets**

# %%
X,Y=data['cleaned_text'],data['sentiment_encoded']

# %%
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.3,stratify=Y,random_state=42)
print(x_train.shape,y_train.shape,x_test.shape,y_test.shape)
# Out:
# (31257,) (31257,) (13396,) (13396,)

# %% [markdown]
# **Tfidf vectorizer**

# %%
tf=TfidfVectorizer()
x_train_tf=tf.fit_transform(x_train)
x_test_tf=tf.fit_transform(x_test)
print(x_train_tf.shape)
print(x_test_tf.shape)
# Out:
# (31257, 29316)
# (13396, 17778)

# %% [markdown]
# # **Trying out different ML models**

# %% [markdown]
# **Logistic regression**

# %%
logistic=LogisticRegression()

# %%
log_cv_score=cross_val_score(logistic,x_train_tf,y_train,cv=5,scoring='f1_macro',n_jobs=-1)

# %%
mean_log_cv=np.mean(log_cv_score)
mean_log_cv
# Out:
# 0.8246116335770693

# %% [markdown]
# **Support vector classifier**

# %%
svc=LinearSVC()

# %%
lin_svc_cv_score=cross_val_score(svc,x_train_tf,y_train,cv=5,scoring='f1_macro',n_jobs=-1)
mean_lin_svc_score=np.mean(lin_svc_cv_score)
mean_lin_svc_score
# Out:
# 0.8211950895905307

# %% [markdown]
# **Naive bayes classifier**

# %%
multinb=MultinomialNB()

# %%
multinb_cv_score=cross_val_score(multinb,x_train_tf,y_train,cv=5,scoring='f1_macro',n_jobs=-1)
mean_multinb_cv=np.mean(multinb_cv_score)
mean_multinb_cv
# Out:
# 0.6727908807470693

# %% [markdown]
# **Decision tree classifier**

# %%
dtree = DecisionTreeClassifier()

# %%
dtree_cv_score = cross_val_score(dtree,x_train_tf,y_train,cv=5,scoring='f1_macro',n_jobs=-1)
mean_dtree_cv = np.mean(dtree_cv_score)
mean_dtree_cv
# Out:
# 0.8066268624574011

# %% [markdown]
# **RandomForest Classifier**

# %%
rand_forest = RandomForestClassifier()

# %%
rand_forest_cv_score = cross_val_score(rand_forest,x_train_tf,y_train,cv=5,scoring='f1_macro',n_jobs=-1)
mean_rand_forest_cv = np.mean(rand_forest_cv_score)
mean_rand_forest_cv
# Out:
# 0.8332644378611512

# %% [markdown]
# **Adaboost Classifier**

# %%
adab = AdaBoostClassifier()

# %%
adab_cv_score = cross_val_score(adab,x_train_tf,y_train,cv=5,scoring='f1_macro',n_jobs=-1)
mean_adab_cv = np.mean(adab_cv_score)
mean_adab_cv
# Out:
# 0.7634834298677198

# %% [markdown]
# By trying different models we can see logistic regression, svm and random forest classifier performed similarly, so among these we will go with svm model as it is more generalised and light

# %% [markdown]
# **Fine Tuning Support Vector Classifier**

# %%
svc1 = LinearSVC()
param_grid = {'C':[0.0001,0.001,0.01,0.1,1,10],
             'loss':['hinge','squared_hinge'],
             'fit_intercept':[True,False]}
grid_search = GridSearchCV(svc1,param_grid,cv=5,scoring='f1_macro',n_jobs=-1,verbose=0,return_train_score=True)
grid_search.fit(x_train_tf,y_train)
# Out:
# GridSearchCV(cv=5, estimator=LinearSVC(), n_jobs=-1,
#              param_grid={'C': [0.0001, 0.001, 0.01, 0.1, 1, 10],
#                          'fit_intercept': [True, False],
#                          'loss': ['hinge', 'squared_hinge']},
#              return_train_score=True, scoring='f1_macro')

# %%
grid_search.best_estimator_
# Out:
# LinearSVC(C=1, loss='hinge')

# %%
grid_search.best_score_
# Out:
# 0.8253264953941878

# %% [markdown]
# **Model Evaluation**

# %%
svc.fit(x_train_tf,y_train)
y_pred = svc.predict(x_test_tf)

# %%
def print_confusion_matrix(confusion_matrix, class_names, figsize = (10,7), fontsize=14):
    df_cm = pd.DataFrame(confusion_matrix, index=class_names, columns=class_names)
    fig = plt.figure(figsize=figsize)
    try:
        heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
    except ValueError:
        raise ValueError("Confusion matrix values must be integers.")
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
    plt.ylabel('Truth')
    plt.xlabel('Prediction')

# %%
cm = confusion_matrix(y_test,y_pred)
print_confusion_matrix(cm,sentiments)

# %%
print('Classification Report:\n',classification_report(y_test, y_pred, target_names=sentiments))
# Out:
# Classification Report:
#                       precision    recall  f1-score   support
#
#            religion       0.99      0.99      0.99      5567
#                 age       0.98      1.00      0.99      5519
#           ethnicity       0.99      1.00      1.00      5439
#              gender       0.97      0.97      0.97      5333
# other_cyberbullying       0.91      0.92      0.91      4047
#   not_cyberbullying       0.92      0.90      0.91      5352
#
#            accuracy                           0.96     31257
#           macro avg       0.96      0.96      0.96     31257
#        weighted avg       0.96      0.96      0.96     31257

# %% [markdown]
# **Saving Model**

# %%
# pickle.dump(tf_idf, open('vectorizer.pkl', 'wb'))
# pickle.dump(lin_svc, open('model.pkl', 'wb'))
